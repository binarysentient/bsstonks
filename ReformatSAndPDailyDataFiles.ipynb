# %%
import pandas as pd
from os import listdir

directory = '../../data/refined_snp_500/'
dataframe = None
for f in listdir(directory):
    print(f)
    if f.endswith('.csv') == True:
        df = pd.read_csv(directory + f)
        df = df.iloc[::-1]
        dataframe = df
    #     df = df.rename(columns = {'Unnamed: 0':'date', '1. open':'open', '2. high':'high', '3. low':'low', '4. close':'close', '5. volume':'volume'})
        df.to_csv('{}/reversed/{}'.format(directory, f), index = False)
# Out:
# SRE.csv
# MAA.csv
# AMD.csv
# HST.csv
# FRC.csv
# KSU.csv
# ALLE.csv
# MAS.csv
# AIG.csv
# CPRT.csv
# POOL.csv
# PKG.csv
# RJF.csv
# FRT.csv
# CFG.csv
# MCO.csv
# STE.csv
# V.csv
# MRO.csv
# TJX.csv
# ICE.csv
# PGR.csv
# EL.csv
# FITB.csv
# FE.csv
# DGX.csv
# CI.csv
# CVS.csv
# CLX.csv
# WEC.csv
# AZO.csv
# PVH.csv
# NWS.csv
# MCHP.csv
# DHR.csv
# NKE.csv
# ANSS.csv
# GIS.csv
# PM.csv
# FCX.csv
# NVR.csv
# DG.csv
# SJM.csv
# SPGI.csv
# ETN.csv
# JCI.csv
# ANET.csv
# COO.csv
# ETR.csv
# EA.csv
# MO.csv
# ESS.csv
# GS.csv
# ADP.csv
# LYV.csv
# PSA.csv
# MCK.csv
# GM.csv
# EBAY.csv
# PYPL.csv
# UHS.csv
# SYF.csv
# PXD.csv
# MNST.csv
# FISV.csv
# LKQ.csv
# UPS.csv
# LMT.csv
# GWW.csv
# BK.csv
# HIG.csv
# NTRS.csv
# CHRW.csv
# FAST.csv
# HBI.csv
# APA.csv
# AJG.csv
# GOOG.csv
# ISRG.csv
# PRU.csv
# KMI.csv
# JBHT.csv
# SNPS.csv
# COP.csv
# VZ.csv
# HLT.csv
# VIAC.csv
# PNC.csv
# PHM.csv
# DE.csv
# SPG.csv
# TSLA.csv
# MTD.csv
# BIO.csv
# HUM.csv
# IP.csv
# DRE.csv
# FMC.csv
# HD.csv
# ...
